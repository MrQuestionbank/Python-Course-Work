# %% [markdown]
# # Python Quiz Game with visualization
# -----

# %%
import matplotlib.pyplot as plt 
Score_History =[]
QuestionBank = [
    {
        "question": "What will be the output of the following code?\nprint(type([]) is list)",
        "options": ["a) True", "b) False", "c) list", "d) None"],
        "answer": "a"
    },
    {
        "question": "Which of the following is used to create an empty set in Python?",
        "options": ["a) {}", "b) set()", "c) []", "d) emptyset()"],
        "answer": "b"
    },
    {
        "question": "What will be the output of bool(0) in Python?",
        "options": ["a) 0", "b) False", "c) True", "d) None"],
        "answer": "b"
    },
    {
        "question": "Which keyword is used to define a function in Python?",
        "options": ["a) define", "b) function", "c) def", "d) func"],
        "answer": "c"
    },
    {
        "question": "What will len(\"Python\"[::-1]) return?",
        "options": ["a) 5", "b) 6", "c) Error", "d) None"],
        "answer": "b"
    },
    {
        "question": "Which of the following is mutable in Python?",
        "options": ["a) String", "b) Tuple", "c) List", "d) Integer"],
        "answer": "c"
    },
    {
        "question": "What is the output of 3 * 'ab'?",
        "options": ["a) ababab", "b) ab3", "c) ab ab ab", "d) Error"],
        "answer": "a"
    },
    {
        "question": "Which of the following removes the last element from a list?",
        "options": ["a) list.remove()", "b) list.pop()", "c) list.delete()", "d) list.discard()"],
        "answer": "b"
    },
    {
        "question": "What is the output of bool(\"False\")?",
        "options": ["a) True", "b) False", "c) 'False'", "d) None"],
        "answer": "a"
    },
    {
        "question": "What will be printed by the code below?\n\nx = [1, 2, 3]\nprint(x * 2)",
        "options": ["a) [1, 2, 3, 1, 2, 3]", "b) [2, 4, 6]", "c) Error", "d) [1, 2, 3, 2]"],
        "answer": "a"
    }
]

# %%
def quiz():
    Total = 0
    for i in QuestionBank: 
        print(i["question"])
        for o in i["options"]:
            print(o)
        ans = input("Enter a Choice: (a/b/c/d) : ").lower()
        if ans == i["answer"]: 
            print("Correct! :) ")
            Total += 1
        else: 
            print("Wrong :(")

    print(f"Your Total is : {Total} Out of 10. ")
    Score_History.append(Total)

# %%
def history_data():
    x_values = list(range(1, len(Score_History) + 1))
    y_values = Score_History

    plt.figure(figsize=(6, 4))
    plt.scatter(x_values, y_values, color='blue')
    plt.plot(x_values, y_values, linestyle='--', alpha=0.7, color='blue')

    plt.xlabel("Attempt Number")
    plt.ylabel("Score")
    plt.title("Score History Tracker")
    plt.xlim(0, len(Score_History) +1 )  # Keep x-axis tight
    plt.ylim(0, max(Score_History) + 1)      # Adjust y-axis based on scores

    plt.show()

# %%
while True: 
    print("Do you want to play the quiz? ")
    a = input("[Y]es or [N]0").lower()
    if a == "n": 
        break
    else: 
        print("Welcome! ")
        quiz()
        history_data()
        break
# Out:
# Do you want to play the quiz?
# Welcome!
# What will be the output of the following code?
# print(type([]) is list)
# a) True
# b) False
# c) list
# d) None
# Wrong :(
# Which of the following is used to create an empty set in Python?
# a) {}
# b) set()
# c) []
# d) emptyset()
# Wrong :(
# What will be the output of bool(0) in Python?
# a) 0
# b) False
# c) True
# d) None
# Wrong :(
# Which keyword is used to define a function in Python?
# a) define
# b) function
# c) def
# d) func
# Correct! :)
# What will len("Python"[::-1]) return?
# a) 5
# b) 6
# c) Error
# d) None
# Wrong :(
# Which of the following is mutable in Python?
# a) String
# b) Tuple
# c) List
# d) Integer
# Correct! :)
# What is the output of 3 * 'ab'?
# a) ababab
# b) ab3
# c) ab ab ab
# d) Error
# Wrong :(
# Which of the following removes the last element from a list?
# a) list.remove()
# b) list.pop()
# c) list.delete()
# d) list.discard()
# Wrong :(
# What is the output of bool("False")?
# a) True
# b) False
# c) 'False'
# d) None
# Wrong :(
# What will be printed by the code below?
#
# x = [1, 2, 3]
# print(x * 2)
# a) [1, 2, 3, 1, 2, 3]
# b) [2, 4, 6]
# c) Error
# d) [1, 2, 3, 2]
# Wrong :(
# Your Total is : 2 Out of 10.
